# %%
Question 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
img = np.zeros((100,100,3), np.uint8)
#cv2_imshow(img)
#@title Color Palatte

B = 255 #@param {type:"slider",min:0, max:255, step:1}
G = 255 #@param {type:"slider",min:0, max:255, step:1}
R = 255 #@param {type:"slider",min:0, max:255, step:1}
CB = True #@param {type:"boolean"}
print(B)
print(R)
print(G)
print(CB)

if CB == False:
  img[:] = 0
else:
  img[:] = [B, G, R]

cv2_imshow(img)
# Out:
# 255
# 255
# 255
# True
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F8176FE26D0>

# %%
Question 2

# %%
import matplotlib.pylab as plt

img=plt.imread('/content/DIP_Lab_Endterm.png')
plt.imshow(img)

mask = np.zeros(img.shape, dtype="uint8")
cv.rectangle(mask, (30,150), (180,280),(512,512,3), -1)
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=RGBA size=339x339 at 0x7F81757AC110>
